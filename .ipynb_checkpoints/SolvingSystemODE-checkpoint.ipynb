# %% [markdown]
# ## Premise
#
# Generate a dataset that follows a simple system of ODEs using interative calculations. Then train a neural network to fit the dataset

# %% [markdown]
# ##### System of ODE:
#
# ${dy_1\over dx} = y_1,$
#
# ${dy_2\over dx}=y_1-y_2,$
#
# with initial conditions of form $y_1(0)=1$ and $y_2(0)=2$

# %% [markdown]
# ## Neural Network Model
#
# Implemented using Pytorch Lightning model. I'm lazy and do not want to manually implement training and epoch loops :3.

# %%
import torch, torch.nn as nn, torch.utils.data as data, torchvision as tv, torch.nn.functional as F
import lightning as L
import numpy as np

class Learner(L.LightningModule):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(1, 50),
            nn.GELU(),
            nn.Linear(50, 100),
            nn.GELU(),
            nn.Linear(100, 500),
            nn.GELU(),
            nn.Linear(500, 500),
            nn.GELU(),
            nn.Linear(500, 100),
            nn.GELU(),
            nn.Linear(100, 50),
            nn.GELU(),
            nn.Linear(50, 2)
        )

    def forward(self, input):
        return self.model(input);

    def training_step(self, batch, batch_idx):
        '''
        Given x, given y = y1, y2
        '''
        x_data, y_data = batch
        y_predicted = self.model(x_data)
        
        loss = nn.MSELoss()(y_data, y_predicted)
        
        self.log("train_loss", loss, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=.0003)
        return optimizer

# %% [markdown]
# ## Dataset Generation
#
# Implemented using torch.data.Dataset. The data is generated by iteratively generating the function by calculating small increments of dx and dy.

# %%
class Dataset(data.Dataset):

    def __init__(self, init, end, n, initial_condition):
        self.n = n
        self.x = torch.linspace(init, end, self.n)
        self.y = initial_condition.unsqueeze(0)
        
        dx = (end - init) / self.n
        for i in range(self.n - 1):
            dy = torch.Tensor([self.y[-1][0], self.y[-1][0] - self.y[-1][1]]) * dx
            new_y = self.y[-1] + dy
            self.y = torch.cat((self.y, new_y.unsqueeze(0)), 0)
    
    def __len__(self):

        return self.n

    def __getitem__(self, idx):
        x = self.x[idx, np.newaxis].to("cuda")
        y = self.y[idx].to("cuda")

        return torch.Tensor(x).to("cuda"), torch.Tensor(y).to("cuda")

# %%
initial_condition = torch.Tensor([1, 2])
train = Dataset(0, 10, 10000, initial_condition)

# %% [markdown]
# Real solution from solving it analytically

# %%
def y_1_analytical(x):
    return torch.exp(x)

def y_2_analytical(x):
    return 0.5 * torch.exp(x) + 1.5 * torch.exp(-x)

# %% [markdown]
# As you can see, the analytical and generate solution are almost the same

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,5))
ax_dataset = fig.add_subplot(121)
ax_dataset.plot(train.x[:], train.y[:, 1])

ax_analytical = fig.add_subplot(122)
ax_analytical.plot(torch.linspace(0, 10, 10000), y_2_analytical(torch.linspace(0, 10, 10000)))

# %% [markdown]
# ## Training

# %%
# C:\Users\zheyu\AppData\Local\Programs\Python\Python312\Scripts
print(torch.version.cuda)
# Out:
# 11.8

# %%
from lightning.pytorch.callbacks.early_stopping import EarlyStopping

early_stop_callback = EarlyStopping(monitor="train_loss", min_delta=0.00, patience=10000, verbose=False, mode="min", stopping_threshold=900)
trainer = L.Trainer(accelerator="cuda", logger=False, max_epochs=10000, callbacks=[early_stop_callback])
learner = Learner()
trainer.fit(learner, data.DataLoader(train, batch_size=100))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 361 K
# -------------------------------------
# 361 K     Trainable params
# 0         Non-trainable params
# 361 K     Total params
# 1.446     Total estimated model params size (MB)
# Training: |                                                                                      | 0/? [00:00<…
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[73], line 6
#       4 trainer = L.Trainer(accelerator="cuda", logger=False, max_epochs=10000, callbacks=[early_stop_callback])
#       5 learner = Learner()
# ----> 6 trainer.fit(learner, data.DataLoader(train, batch_size=100))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\trainer.py:544, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     542 self.state.status = TrainerStatus.RUNNING
#     543 self.training = True
# --> 544 call._call_and_handle_interrupt(
#     545     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     546 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\trainer.py:580, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     573 assert self.state.fn is not None
#     574 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     575     self.state.fn,
#     576     ckpt_path,
#     577     model_provided=True,
#     578     model_connected=self.lightning_module is not None,
#     579 )
# --> 580 self._run(model, ckpt_path=ckpt_path)
#     582 assert self.state.stopped
#     583 self.training = False
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\trainer.py:987, in Trainer._run(self, model, ckpt_path)
#     982 self._signal_connector.register_signal_handlers()
#     984 # ----------------------------
#     985 # RUN THE TRAINER
#     986 # ----------------------------
# --> 987 results = self._run_stage()
#     989 # ----------------------------
#     990 # POST-Training CLEAN UP
#     991 # ----------------------------
#     992 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1033, in Trainer._run_stage(self)
#    1031         self._run_sanity_check()
#    1032     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1033         self.fit_loop.run()
#    1034     return None
#    1035 raise RuntimeError(f"Unexpected state {self.state}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:206, in _FitLoop.run(self)
#     204     self.on_advance_start()
#     205     self.advance()
# --> 206     self.on_advance_end()
#     207     self._restarting = False
#     208 except StopIteration:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:378, in _FitLoop.on_advance_end(self)
#     376 call._call_callback_hooks(trainer, "on_train_epoch_end", monitoring_callbacks=False)
#     377 call._call_lightning_module_hook(trainer, "on_train_epoch_end")
# --> 378 call._call_callback_hooks(trainer, "on_train_epoch_end", monitoring_callbacks=True)
#     380 trainer._logger_connector.on_epoch_end()
#     382 if self.epoch_loop._num_ready_batches_reached():
#     383     # if we are restarting and the above condition holds, it's because we are reloading an epoch-end checkpoint.
#     384     # since metric-based schedulers require access to metrics and those are not currently saved in the
#     385     # checkpoint, the plateau schedulers shouldn't be updated
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\trainer\call.py:208, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     206     if callable(fn):
#     207         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 208             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     210 if pl_module:
#     211     # restore current_fx when nested context
#     212     pl_module._current_fx_name = prev_fx_name
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:324, in ModelCheckpoint.on_train_epoch_end(self, trainer, pl_module)
#     322 monitor_candidates = self._monitor_candidates(trainer)
#     323 if self._every_n_epochs >= 1 and (trainer.current_epoch + 1) % self._every_n_epochs == 0:
# --> 324     self._save_topk_checkpoint(trainer, monitor_candidates)
#     325 self._save_last_checkpoint(trainer, monitor_candidates)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:386, in ModelCheckpoint._save_topk_checkpoint(self, trainer, monitor_candidates)
#     384     self._save_monitor_checkpoint(trainer, monitor_candidates)
#     385 else:
# --> 386     self._save_none_monitor_checkpoint(trainer, monitor_candidates)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:717, in ModelCheckpoint._save_none_monitor_checkpoint(self, trainer, monitor_candidates)
#     714 self._save_checkpoint(trainer, filepath)
#     716 if self.save_top_k == 1 and previous and self._should_remove_checkpoint(trainer, previous, filepath):
# --> 717     self._remove_checkpoint(trainer, previous)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:800, in ModelCheckpoint._remove_checkpoint(self, trainer, filepath)
#     798 def _remove_checkpoint(self, trainer: "pl.Trainer", filepath: str) -> None:
#     799     """Calls the strategy to remove the checkpoint file."""
# --> 800     trainer.strategy.remove_checkpoint(filepath)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\pytorch\strategies\strategy.py:501, in Strategy.remove_checkpoint(self, filepath)
#     494 """Remove checkpoint filepath from the filesystem.
#     495
#     496 Args:
#     497     filepath: Path to checkpoint
#     498
#     499 """
#     500 if self.is_global_zero:
# --> 501     self.checkpoint_io.remove_checkpoint(filepath)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning\fabric\plugins\io\torch_io.py:95, in TorchCheckpointIO.remove_checkpoint(self, path)
#      93 fs = get_filesystem(path)
#      94 if fs.exists(path):
# ---> 95     fs.rm(path, recursive=True)
#      96     log.debug(f"Removed checkpoint: {path}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\fsspec\implementations\local.py:174, in LocalFileSystem.rm(self, path, recursive, maxdepth)
#     172     shutil.rmtree(p)
#     173 else:
# --> 174     os.remove(p)
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:/Users/zheyu/OneDrive/Documents/GitHub/Senior-Project/checkpoints/epoch=852-step=85300.ckpt'

# %% [markdown]
# ## Evaluating Predictions

# %%
y_hat = learner.model.forward(train.x.view(10000, 1).to("cuda"))
y_hat = y_hat.detach().cpu()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 y_hat = learner.model.forward(train.x.view(10000, 1).to("cuda"))
#       2 y_hat = y_hat.detach().cpu()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %%
fig = plt.figure(figsize=(10,5))
ax_y1 = fig.add_subplot(121)
ax_y1.plot(train.x[:], train.y[:, 0], color='blue')
ax_y1.plot(train.x[:], y_hat[:, 0], color='orange')

ax_y2 = fig.add_subplot(122)
ax_y2.plot(train.x[:], train.y[:, 1], color='blue')
ax_y2.plot(train.x[:], y_hat[:, 1], color='orange')

# %% [markdown]
# That's surprising. The loss function wasn't converging yet the resulting graphs are pretty similar to the real functions. The loss was also pretty large...wut dis dont make no sense. :|

# %%
print(y_hat)
print(train.y)
# Out:
# tensor([[3.0017e+01, 1.6374e+01],
#         [3.0011e+01, 1.6369e+01],
#         [3.0005e+01, 1.6365e+01],
#         ...,
#         [2.1779e+04, 1.0912e+04],
#         [2.1797e+04, 1.0921e+04],
#         [2.1815e+04, 1.0930e+04]])
# tensor([[1.0000e+00, 2.0000e+00],
#         [1.0010e+00, 1.9990e+00],
#         [1.0020e+00, 1.9980e+00],
#         ...,
#         [2.1851e+04, 1.0926e+04],
#         [2.1873e+04, 1.0936e+04],
#         [2.1895e+04, 1.0947e+04]])
